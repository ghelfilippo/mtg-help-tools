# %% [markdown]
# ### Ideal Land formula

# %%
from lib import neededLands

neededLands(3.87, 17)
# Out:
# Suggested lands are 38.8

# %% [markdown]
# ### Ramp calculator

# %%
from lib import calculateDropPerTurn

RAMP = [
    {
        "mv" : 1, ####### esempio di sol ring
        "quantity" : 1,
        "ramp" : 2
    },
    {
        "mv" : 1,  ###### uccelli del paradiso
        "quantity" : 4,
        "ramp" : 1
    },
    {
        "mv" : 2, ###### farseek
        "quantity" : 8,
        "ramp" : 1
    },
    {
        "mv" : 3, ##### cultivate
        "quantity" : 2,
        "ramp" : 1
    },
    {
        "mv" : 3, ### urza incubator
        "quantity" : 1,
        "ramp" : 2
    }
]

LANDS = 38 ######## IL NUMERO DI TERRE NEL TUO MAZZO

TARGET = 5 ######## IL TARGET DEL TUO MAZZO, AD ESEMPIO IL COSTO DI MANA DEL COMANDANTE


calculateDropPerTurn(TARGET, LANDS, RAMP,  min_ramp = 1, min_land = 3, max_mulligans = 1, simulation=20000)
# Out:
#     turno  percentuale cumulativa di successo
# 0       3                              25.360
# 1       4                              80.165
# 2       5                              91.830
# 3       6                              95.280
# 4       7                              97.270
# 5       8                              98.500
# 6       9                              99.140
# 7      10                              99.510
# 8      11                              99.770
# 9      12                              99.885
# 10     13                              99.945
# 11     14                              99.980
# 12     15                             100.000

# %%
from lib.utils import initializeDeckList, getCardInfo

initializeDeckList()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from lib.utils import initializeDeckList, getCardInfo
# ----> 3 initializeDeckList()
#
# File ~/Documents/mtg-help-tools/lib/utils.py:199, in initializeDeckList(path_input, path_output)
#     197 with open(path_input, 'r') as file:
#     198     for card in file:
# --> 199         quantiy, name, category, mv , produced_mana = parseRow(card, known_cards)
#     200         if category not in parsed.keys():
#     201             parsed[category] = []
#
# TypeError: parseRow() takes 1 positional argument but 2 were given

# %%
getCardInfo('Game Trail')
# Out:
# {'object': 'card',
#  'id': '2a84a604-7b05-4716-bcd8-40d2acdb76e8',
#  'oracle_id': '00de57d2-7cb6-4337-9bc6-f6711e4dfabf',
#  'multiverse_ids': [650358],
#  'mtgo_id': 122676,
#  'tcgplayer_id': 535869,
#  'cardmarket_id': 753483,
#  'name': 'Game Trail',
#  'lang': 'en',
#  'released_at': '2024-02-09',
#  'uri': 'https://api.scryfall.com/cards/2a84a604-7b05-4716-bcd8-40d2acdb76e8',
#  'scryfall_uri': 'https://scryfall.com/card/mkc/264/game-trail?utm_source=api',
#  'layout': 'normal',
#  'highres_image': True,
#  'image_status': 'highres_scan',
#  'image_uris': {'small': 'https://cards.scryfall.io/small/front/2/a/2a84a604-7b05-4716-bcd8-40d2acdb76e8.jpg?1706241163',
#   'normal': 'https://cards.scryfall.io/normal/front/2/a/2a84a604-7b05-4716-bcd8-40d2acdb76e8.jpg?1706241163',
#   'large': 'https://cards.scryfall.io/large/front/2/a/2a84a604-7b05-4716-bcd8-40d2acdb76e8.jpg?1706241163',
# ...
